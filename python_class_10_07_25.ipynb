# %% [markdown]
# # Agenda
# 1. Variables
# 2. Python Operators, arithmetics, flow control
# 3. Data Types
# 4. Data Structures
# 5. Python Iterations
# 6. Functions
# 7. Questions

# %% [markdown]
# ## Variables
# 1. no spaces in a variable name
# 2. all letters small letters except when defining a constant
# 3. camel case for example: user_age
# 4. meaningful names

# %%
first_name = "John"
last_name = 'joe'
age = 22
height = 150
weight = 70.5
waist = 40.3
likes_adventure = True
likes_walking = True
likes_swimming = False

# %% [markdown]
# ## Python Operators, arithmetics, flow control

# %%
a = 1
b = 2

# %%
a + b
# Out:
# 3

# %%
a - b
# Out:
# -1

# %%
a * b
# Out:
# 2

# %%
c = 3
d = 4

# %%
c ** b
# Out:
# 9

# %%
d / b
# Out:
# 2.0

# %%
d / c
# Out:
# 1.3333333333333333

# %%
8 % 3
# Out:
# 2

# %%
9 // 3
# Out:
# 3

# %%
d // b
# Out:
# 2

# %%
# operators: 
# When operators are used they return a boolean
# 1. greater than >
# 2. less than <
# 3. equal to == 
# 4. not equal to != 
# 5. less than or equal to <=
# 6. greater than or equal >=

# %%
a
# Out:
# 1

# %%
b
# Out:
# 2

# %%
c
# Out:
# 3

# %%
d
# Out:
# 4

# %%
a > b
# Out:
# False

# %%
a < b
# Out:
# True

# %%
a >= b
# Out:
# False

# %%
a <= b
# Out:
# True

# %%
a == b
# Out:
# False

# %%
a != b
# Out:
# True

# %%
# and or

# %%
a <= b or a == b
# Out:
# True

# %%
# Data Types - 
# integer - int
# numeric - float
# text - str
# boolean - bool

# %%
# flow control allows to perform conditional statements.
# A condition is a boolean. 
# In simple words, a condition is anything that returns a true or a false

# %%
age
# Out:
# 22

# %%
if age >= 18:
    print("You are now an adult")
else:
    print("Not yet. Keep doing your thing!")
# Out:
# You are now an adult

# %%
age = input("What is your age: ") # a str - '2'
age = int(age)

if age > 0 and age < 5:
    print("Still a child")
elif age > 5 and age <18:
    print("Teenager")
elif age >= 18 and age <= 35:
    print("Adult")
else:
    print("You are getting old")
# Out:
# What is your age: 32
# Adult

# %% [markdown]
# ## Data Structures
# 1. List
# 2. Tuple
# 3. Set
# 4. Dictionary

# %% [markdown]
# 1. A list can be made of different data types
# 2. A list is ordered

# %%
fruits = ["apple", "cheery", "pineapple", "watermelon", "apple"]

# %%
fruits[0]
# Out:
# 'apple'

# %%
fruits[1]
# Out:
# 'cheery'

# %%
fruits[-1]
# Out:
# 'apple'

# %%
alist = [2, "jeff", 3.5, True]

# %%
alist[1]
# Out:
# 'jeff'

# %%
alist[3]
# Out:
# True

# %% [markdown]
# 1. A tuple is created with ()
# 2. A tuple cannot be modified
# 3. It can be made of different data types
# 4. A tuple is ordered

# %%
fruits_tuple = ("apple", "cheery", "pineapple", "watermelon", "apple")

# %%
fruits_tuple[0]
# Out:
# 'apple'

# %% [markdown]
# 1. sets are unordered
# 2. A set is created {}
# 3. A set can be made of different data types

# %%
fruits_sets = {"apple", "cheery", "pineapple", "watermelon", "apple"}

# %%
fruits_sets
# Out:
# {'apple', 'cheery', 'pineapple', 'watermelon'}

# %%
fruits
# Out:
# ['apple', 'cheery', 'pineapple', 'watermelon', 'apple']

# %%
set(fruits)
# Out:
# {'apple', 'cheery', 'pineapple', 'watermelon'}

# %% [markdown]
# A dictionary contains a word and a definition.
# A word is called the key and the definition is called the value.
#
# 1. A dictionary is a set of key value pairs
# 2. The keys are unique
# 3. It is unordered
# 4. The key can either be a string or number. they must be unique

# %%
meals = {
    "breakfast": "English breakfast",
    "lunch": "Pasta",
    "dinner": "Steak"
}

# %%
meals["breakfast"]
# Out:
# 'English breakfast'

# %%
meals["lunch"]
# Out:
# 'Pasta'

# %%
meals["dinner"]
# Out:
# 'Steak'

# %%
meals["last_supper"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_1620\2803006316.py in <module>
# ----> 1 meals["last_supper"]
#
# KeyError: 'last_supper'

# %% [markdown]
# ## Python Iterations
# - for loop
# - while loop

# %%
fruits
# Out:
# ['apple', 'cheery', 'pineapple', 'watermelon', 'apple']

# %%
for fruit in fruits:
    print(fruit)
# Out:
# apple
# cheery
# pineapple
# watermelon
# apple

# %%
for i in fruits_tuple:
    print(i)
# Out:
# apple
# cheery
# pineapple
# watermelon
# apple

# %%
for meal in meals:
    print(meal)
# Out:
# breakfast
# lunch
# dinner

# %%
for meal in meals:
    print("meal: ", meal, "menu: ", meals[meal])
# Out:
# meal:  breakfast menu:  English breakfast
# meal:  lunch menu:  Pasta
# meal:  dinner menu:  Steak

# %% [markdown]
# 1. A while loop needs a condition
# 2. It also needs a termination condition

# %%
a = 1

# %%
while a <=5:
    print(a)
    a = a + 1
# Out:
# 1
# 2
# 3
# 4
# 5

# %%
a
# Out:
# 6

# %% [markdown]
# ## Functions
# 1. Functions attached to a variable
# 2. Python Builtin functions
# 3. Custome functions

# %%
first_name
# Out:
# 'John'

# %%
last_name
# Out:
# 'joe'

# %%
type(first_name)
# Out:
# str

# %%
first_name + last_name
# Out:
# 'Johnjoe'

# %%
first_name + " " + last_name
# Out:
# 'John joe'

# %%
# variable_name.func_name(inputs)

# %%
first_name.title() + " " + last_name.title()
# Out:
# 'John Joe'

# %%
'2'.zfill(5)
# Out:
# '00002'
